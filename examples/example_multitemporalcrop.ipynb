# %% [markdown]
# ## MultiTemporalCrop Example

# %%
# !pip install git+https://github.com/IBM/terratorch.git
# Out:
# Collecting git+https://github.com/IBM/terratorch.git
#   Cloning https://github.com/IBM/terratorch.git to /tmp/pip-req-build-j6vg_h1r
#   Running command git clone --filter=blob:none --quiet https://github.com/IBM/terratorch.git /tmp/pip-req-build-j6vg_h1r
#   Resolved https://github.com/IBM/terratorch.git to commit 703f002b7102bcf0eaf6f67f6d788fbb81a73838
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>2.0 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.11.0+cu128)
# Requirement already satisfied: numpy>=2.2 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.5.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.26.0+cu128)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.23.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.0.8)
# Requirement already satisfied: albucore in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.0.24)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.5.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.9.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.1.4)
# Requirement already satisfied: lightly==1.5.22 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.5.22)
# Requirement already satisfied: h5py in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (3.16.0)
# Requirement already satisfied: lightning>=2.6.0 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.6.5)
# Requirement already satisfied: segmentation-models-pytorch>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.5.0)
# Requirement already satisfied: jsonargparse>=4.40.0 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (4.51.0)
# Requirement already satisfied: torchgeo<0.10,>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.9.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.8.2)
# Requirement already satisfied: timm>=1.0.15 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.0.28)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.0.11)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.27.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2026.8.16)
# Requirement already satisfied: python-box in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (7.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (4.67.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (2.20.0)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.39.0)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (0.25.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (18.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.13/dist-packages (from terratorch==1.2.11) (3.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2026.7.22)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (1.3.5)
# Requirement already satisfied: lightly_utils~=0.0.0 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (0.0.2)
# Requirement already satisfied: python_dateutil>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2.32.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (1.17.0)
# Requirement already satisfied: pydantic>=1.10.5 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2.13.4)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2.6.5)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (2.5.0)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.13/dist-packages (from lightly==1.5.22->terratorch==1.2.11) (3.1.17)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.13/dist-packages (from jsonargparse>=4.40.0->terratorch==1.2.11) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from lightning>=2.6.0->terratorch==1.2.11) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in /usr/local/lib/python3.13/dist-packages (from lightning>=2.6.0->terratorch==1.2.11) (26.3)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.13/dist-packages (from lightning>=2.6.0->terratorch==1.2.11) (4.16.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.3.2->terratorch==1.2.11) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.3.2->terratorch==1.2.11) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.3.2->terratorch==1.2.11) (3.6.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from segmentation-models-pytorch>=0.5.0->terratorch==1.2.11) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.13/dist-packages (from segmentation-models-pytorch>=0.5.0->terratorch==1.2.11) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->terratorch==1.2.11) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->terratorch==1.2.11) (3.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->terratorch==1.2.11) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->terratorch==1.2.11) (0.28.1)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>2.0->terratorch==1.2.11) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>2.0->terratorch==1.2.11) (12.8.90)
# Requirement already satisfied: kornia>=0.8.2 in /usr/local/lib/python3.13/dist-packages (from torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (0.8.3)
# Requirement already satisfied: matplotlib>=3.7.3 in /usr/local/lib/python3.13/dist-packages (from torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (3.10.0)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (2.2.3)
# Requirement already satisfied: pyproj>=3.6.1 in /usr/local/lib/python3.13/dist-packages (from torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (3.7.2)
# Requirement already satisfied: shapely>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.13/dist-packages (from geopandas->terratorch==1.2.11) (0.13.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.13/dist-packages (from rasterio->terratorch==1.2.11) (3.0.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.13/dist-packages (from rasterio->terratorch==1.2.11) (26.1.0)
# Requirement already satisfied: pyparsing>=3.0 in /usr/local/lib/python3.13/dist-packages (from rasterio->terratorch==1.2.11) (3.3.2)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.13/dist-packages (from albucore->terratorch==1.2.11) (5.1.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.13/dist-packages (from albucore->terratorch==1.2.11) (6.5.16)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.13/dist-packages (from albucore->terratorch==1.2.11) (5.0.0.93)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.13/dist-packages (from diffusers->terratorch==1.2.11) (9.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.13/dist-packages (from diffusers->terratorch==1.2.11) (2025.11.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->terratorch==1.2.11) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->terratorch==1.2.11) (2.21.0)
# Requirement already satisfied: xarray>=2026.2 in /usr/local/lib/python3.13/dist-packages (from rioxarray->terratorch==1.2.11) (2026.7.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.13/dist-packages (from scikit-image->terratorch==1.2.11) (2.37.4)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.13/dist-packages (from scikit-image->terratorch==1.2.11) (0.5)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (1.83.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (3.10.3)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard->terratorch==1.2.11) (3.1.8)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>2.0->terratorch==1.2.11) (1.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->terratorch==1.2.11) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->terratorch==1.2.11) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->terratorch==1.2.11) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->terratorch==1.2.11) (0.16.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.13/dist-packages (from hydra-core>=1.0.0->lightly==1.5.22->terratorch==1.2.11) (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.13/dist-packages (from hydra-core>=1.0.0->lightly==1.5.22->terratorch==1.2.11) (4.9.3)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.13/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (0.18.0)
# Requirement already satisfied: typeshed-client>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (2.13.0)
# Requirement already satisfied: kornia-rs>=0.1.9 in /usr/local/lib/python3.13/dist-packages (from kornia>=0.8.2->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (0.1.14)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->terratorch==1.2.11) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.3->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.3->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.3->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.3->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.1.1->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.1.1->torchgeo<0.10,>=0.9.0->terratorch==1.2.11) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.10.5->lightly==1.5.22->terratorch==1.2.11) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.10.5->lightly==1.5.22->terratorch==1.2.11) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.10.5->lightly==1.5.22->terratorch==1.2.11) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.27.0->lightly==1.5.22->terratorch==1.2.11) (3.4.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>2.0->terratorch==1.2.11) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard->terratorch==1.2.11) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib_metadata->diffusers->terratorch==1.2.11) (4.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.6.0->terratorch==1.2.11) (1.24.5)

# %%
import os
import sys
import numpy as np
import torch

import terratorch
from terratorch.datamodules import MultiTemporalCropClassificationDataModule
from terratorch.tasks import SemanticSegmentationTask
from terratorch.datasets.transforms import FlattenTemporalIntoChannels, UnflattenTemporalFromChannels

import albumentations
from albumentations import Compose, Flip
from albumentations.pytorch import ToTensorV2

import lightning.pytorch as pl
from lightning.pytorch.loggers import TensorBoardLogger
from lightning.pytorch.callbacks import ModelCheckpoint

# %% [markdown]
# If you have the data already downloaded, update the `DATASET_PATH`. Otherwise, download it with the following code. Check [here](https://huggingface.co/datasets/ibm-nasa-geospatial/multi-temporal-crop-classification) for more details on this dataset.

# %%
DATASET_PATH = "./data"

# %%
from huggingface_hub import snapshot_download

repo_id = "ibm-nasa-geospatial/multi-temporal-crop-classification"
_ = snapshot_download(repo_id=repo_id, repo_type="dataset", cache_dir="./cache", local_dir=DATASET_PATH)

# %%
OUT_DIR = "./multicrop_example"  # where to save checkpoints and log files

BATCH_SIZE = 16
EPOCHS = 50
LR = 2.0e-4
WEIGHT_DECAY = 0.1
HEAD_DROPOUT=0.1
FREEZE_BACKBONE = False

BANDS = ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"]
NUM_FRAMES = 3

CLASS_WEIGHTS = [
    0.386375, 0.661126, 0.548184, 0.640482, 0.876862, 0.925186, 3.249462,
    1.542289, 2.175141, 2.272419, 3.062762, 3.626097, 1.198702
]

SEED = 0

# %% [markdown]
# #### Exploring the dataset

# %%
# Adding augmentations for a temporal dataset requires additional transforms
train_transforms = [
    terratorch.datasets.transforms.FlattenTemporalIntoChannels(),
    albumentations.Flip(),
    albumentations.pytorch.transforms.ToTensorV2(),
    terratorch.datasets.transforms.UnflattenTemporalFromChannels(n_timesteps=NUM_FRAMES),
]

# %%
# This datamodule allows access to the dataset in its various splits.
data_module = MultiTemporalCropClassificationDataModule(
    data_root=DATASET_PATH,
    train_transform=train_transforms,
    expand_temporal_dimension=True,
)

# %%
# Checking the dataset means and stds
data_module.means, data_module.stds

# %%
# Checking train split size
data_module.setup("fit")
train_dataset = data_module.train_dataset
len(train_dataset)

# %%
# Checking available bands
train_dataset.all_band_names

# %%
# Checking dataset classes
train_dataset.class_names

# %%
# Ploting a few samples
for i in range(5):
    train_dataset.plot(train_dataset[i])

# %%
# Checking validation split size
val_dataset = data_module.val_dataset
len(val_dataset)

# %%
# Checking test split
data_module.setup("test")
test_dataset = data_module.test_dataset
len(test_dataset)

# %% [markdown]
# #### Training setup

# %%
pl.seed_everything(SEED)

# Logger
logger = TensorBoardLogger(
    save_dir=OUT_DIR,
    name="multicrop_example",
)

# Callbacks
checkpoint_callback = ModelCheckpoint(
    monitor="val/Multiclass_Jaccard_Index",
    mode="max",
    dirpath=os.path.join(OUT_DIR, "multicrop_example", "checkpoints"),
    filename="best-checkpoint-{epoch:02d}-{val_loss:.2f}",
    save_top_k=1,
)

# Trainer
trainer = pl.Trainer(
    accelerator="auto",
    strategy="auto",
    devices="auto",
    precision="bf16-mixed",
    num_nodes=1,
    logger=logger,
    max_epochs=EPOCHS,
    check_val_every_n_epoch=1,
    log_every_n_steps=10,
    enable_checkpointing=True,
    callbacks=[checkpoint_callback],
    limit_predict_batches=1,  # predict only in the first batch for generating plots
)

# DataModule
data_module = MultiTemporalCropClassificationDataModule(
    batch_size=BATCH_SIZE,
    data_root=DATASET_PATH,
    train_transform=train_transforms,
    reduce_zero_label=True,
    expand_temporal_dimension=True,
    num_workers=7,
    use_metadata=True,
)

# %%
# Model

backbone_args = dict(
    backbone_pretrained=True,
    backbone="prithvi_eo_v2_300_tl", # prithvi_eo_v2_300, prithvi_eo_v2_300_tl, prithvi_eo_v2_600, prithvi_eo_v2_600_tl
    backbone_coords_encoding=["time", "location"],
    backbone_bands=BANDS,
    backbone_num_frames=NUM_FRAMES,
)

decoder_args = dict(
    decoder="UperNetDecoder",
    decoder_channels=256,
    decoder_scale_modules=True,
)

necks = [
    dict(
            name="SelectIndices",
            # indices=[2, 5, 8, 11]    # indices for prithvi_vit_100
            indices=[5, 11, 17, 23],   # indices for prithvi_eo_v2_300
            # indices=[7, 15, 23, 31]  # indices for prithvi_eo_v2_600
        ),
    dict(
            name="ReshapeTokensToImage",
            effective_time_dim=NUM_FRAMES,
        )
    ]

model_args = dict(
    **backbone_args,
    **decoder_args,
    num_classes=len(CLASS_WEIGHTS),
    head_dropout=HEAD_DROPOUT,
    necks=necks,
    rescale=True,
)


model = SemanticSegmentationTask(
    model_args=model_args,
    plot_on_val=False,
    class_weights=CLASS_WEIGHTS,
    loss="ce",
    lr=LR,
    optimizer="AdamW",
    optimizer_hparams=dict(weight_decay=WEIGHT_DECAY),
    ignore_index=-1,
    freeze_backbone=FREEZE_BACKBONE,
    freeze_decoder=False,
    model_factory="EncoderDecoderFactory",
)

# %% [markdown]
# #### Training and testing the model

# %%
# Training
trainer.fit(model, datamodule=data_module)

# %%
ckpt_path = checkpoint_callback.best_model_path

# Test results
test_results = trainer.test(model, datamodule=data_module, ckpt_path=ckpt_path)

# %%
test_results

# %% [markdown]
# #### Plot predictions

# %%
# Now we can use the model to generate predictions and visualize results
# As we set limit_predict_batches=1, only the first batch will be used

preds = trainer.predict(model, datamodule=data_module, ckpt_path=ckpt_path)

# %%
# Get first batch of samples for plotting

data_loader = trainer.predict_dataloaders
batch = next(iter(data_loader))

# %%
# Plot samples and respective predictions

for i in range(BATCH_SIZE):

    sample = {key: batch[key][i] for key in batch}
    sample["prediction"] = preds[0][0][i].cpu().numpy()

    data_module.predict_dataset.plot(sample)
